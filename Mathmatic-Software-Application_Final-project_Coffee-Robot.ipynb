# %% [markdown]
# # 主題:咖啡廳機器人
# # 成員:會計三孫瑄正 會計三劉亮緯 資管三曾煜祐 哲學四李錦藤 經濟四傅俞瑄

# %%
import pandas as pd
coffeebean = pd.DataFrame([["衣索比亞 谷吉 吉德處理廠","日曬","淺中焙","花香/覆盆子/藍莓","藍莓果汁/杏桃/茶香","$100"],
                ["哥斯大黎加 阿葛利惟德 帝比卡","白蜜處理","淺中焙","麥芽/奶油香氣","麥芽/杏仁/堅果巧克力","$125"],
                ["巴拿馬 摩根莊園 藝伎","水洗","淺中焙","檸檬/茉莉花/咖啡花","柳橙/柚子/焦糖/可可","$200"]],
                columns = ["產區","處理法","焙度","香氣","風味","價格"],index=["1","2","3"])
import time
print('cafe：您好，歡迎光臨咖啡廳')
print('cafe：請問今天需要什麼嗎？咖啡、甜點還是純聊天？')
reply = input('you：')
if any(i in reply for i in("coffee","咖啡","COFFEE","Coffee" )):
    print("cafe：店裡目前有單品、義式濃縮，以及拿鐵可供選擇喔!")
    a2 = input("you：")
    #單品#肥宅介紹
    if any(i in a2 for i in("單品","single origin","espresso")):
        print("cafe：這是本期豆單提供您參考，決定後再麻煩您通知我^^")
        print(coffeebean)
        a4 = input("you：")
        print("cafe：請問沖煮方式要用手沖、賽風還是愛樂壓呢?")
        a5 = input("you：")
        print("cafe：好的，ㄧ杯以"+a5+'沖煮的'+a4+'，請稍等一下')
        time.sleep(1)
        print('cafe：你點的咖啡好囉~')
        print("cafe：為你介紹一下，這支豆子有明顯的茉莉花香，甜度豐富，body飽滿，色澤偏紅是它的特色")
        time.sleep(1)
        print("cafe：我也非常喜歡這隻豆子的甜感")
        time.sleep(1)
        print("cafe：就我像喜歡你全糖的笑容一樣")
        time.sleep(1)
        print("cafe：可以讓我成為你專屬的螞蟻嗎?=)")
        time.sleep(2)
        print("cafe：我的line就跟wifi密碼一樣<3")
        time.sleep(2)
        print('cafe：你要聊聊天ㄇ，我想更了解你一點?')
        a100 = input("you：")
            
    #義式濃縮
    elif any(i in a2 for i in("濃縮","義式","espresso")):
        print('cafe：好的，ㄧ杯義式濃縮咖啡，請稍等一下')
        time.sleep(1)
        print('cafe：你點的咖啡好了')
        time.sleep(2)
        print('cafe：你要聊聊天ㄇ，我想更了解你一點?')
        a100 = input("you：")
        
    #拿鐵#JOJO魔法
    elif any(i in a2 for i in("拿鐵","拿","Latte","latte")):
        print("cafe：請您選擇一種喜歡的圖案，選擇好之後再麻煩通知我^^")
        print('cafe："愛心","三葉","天鵝"')
        a5 = input("you：")
        if any(i in a5 for i in("愛心","三葉","天鵝")):
            print("cafe：好的，ㄧ杯"+a5+'的拉花拿鐵，請稍等一下')
            time.sleep(1)
            print("cafe：這是我為你特製的拿鐵歐~")
            print("cafe：讓我幫你施加魔法嗎")
            print("cafe：來，1")
            time.sleep(1)
            print("cafe：2")
            time.sleep(1)
            print("cafe：3")
            time.sleep(2)
            print("cafe：JoJo~")
            time.sleep(2)
            print('cafe：你要聊聊天ㄇ，我想更了解你一點?')
            a100 = input("you：")
            
elif any(i in reply for i in("dessert","cake","蛋糕","點心","甜點")):
    print("cafe：您要哪一種呢?")
    print("cafe：店裡目前有豪豪ㄘ巧克力蛋糕、敲好ㄘ抹茶蛋糕和大力水手卜派")
    a3 = input("you：")
    print("cafe：好的，ㄧ份"+a3+'，請稍等一下')
    time.sleep(1)
    print('cafe：這是您的點心，請慢用')
    print("cafe：小提醒:你點的"+a3+"，每100公克，有熱量260大卡，蛋白質14.6克，脂肪58公克，還有很多很多糖")
    time.sleep(1)
    print("cafe：你媽知道你在這吃垃圾食物嗎?")
    time.sleep(1)
    print("cafe：還不給我滾去健身房深蹲")
    time.sleep(2)
    print('cafe：你要聊聊天ㄇ，我想更了解你一點?')
    a100 = input("you：")
    
elif any(i in reply for i in("聊天","chat","談談","講","說","聊聊")):
    開心=["開心","高興","興奮","好"]
    傷心=["難過","傷心","累","沮喪","不好","不太好"]
    print("cafe：最近還好嗎?")
    chat=[]
    LastTalk=[]
    bye=["再見", "掰","不想講了","閉嘴","他媽的","幹","煩","滾","垃圾"]
    i=0
    a6 = input("you：")
    while not any(i in a6 for i in bye):
        chat.append(a6)
        print("cafe：真的"+chat[i]+"嗎?")
        a6 = input("you：")
        i+=1
    print("cafe：...抱歉我重問")
    print("cafe：最近還好嗎?")
    a7 = input("you：")
    while not any(i in LastTalk for i in bye):
        LastTalk.append(a7)    
        if any(i in a7 for i in 開心):
            print("cafe：你真棒")
            print("cafe：再多說一點")
            a7 = input("you：")
            LastTalk.append(a7)
        elif any(i in a7 for i in 傷心):
            print("cafe：拍拍")
            print("cafe：再多說一點")
            a7 = input("you：")
            LastTalk.append(a7)
        else:
            print("cafe：不太懂")
            print("cafe：再多說一點")
            a7 = input("you：")
            LastTalk.append(a7)
    print("cafe：還有嗎？")
    a7 = input("you：")
    LastTalk.append(a7)
else:
    print("cafe：這裡沒有"+reply+"，直走左轉出口，感謝您的光臨")
    
if any(i in a100 for i in("聊天","chat","談談","講","說","聊聊")):
    開心=["開心","高興","興奮","好"]
    傷心=["難過","傷心","累","沮喪","不好","不太好"]
    print("cafe：最近還好嗎?")
    chat=[]
    LastTalk=[]
    bye=["再見", "掰","不想講了","閉嘴","他媽的","幹","煩","滾","垃圾"]
    i=0
    a6 = input("you：")
    while not any(i in a6 for i in bye):
        chat.append(a6)
        print("cafe：真的"+chat[i]+"嗎?")
        a6 = input("you：")
        i+=1
    print("cafe：...抱歉我重問")
    print("cafe：最近還好嗎?")
    a7 = input("you：")
    while not any(i in LastTalk for i in bye):
        LastTalk.append(a7)    
        if any(i in a7 for i in 開心):
            print("cafe：你真棒")
            print("cafe：再多說一點")
            a7 = input("you：")
            LastTalk.append(a7)
        elif any(i in a7 for i in 傷心):
            print("cafe：拍拍")
            print("cafe：再多說一點")
            a7 = input("you：")
            LastTalk.append(a7)
        else:
            print("cafe：不太懂")
            print("cafe：再多說一點")
            a7 = input("you：")
            LastTalk.append(a7)
    print("cafe：還有嗎？")
    a7 = input("you：")
    LastTalk.append(a7)
else:
    print("cafe：請慢用")
# Out:
# cafe：您好，歡迎光臨咖啡廳
# cafe：請問今天需要什麼嗎？咖啡、甜點還是純聊天？
# you：我不想喝咖啡
# cafe：店裡目前有單品、義式濃縮，以及拿鐵可供選擇喔!
